# %%
# Install PyCaret
# !pip install pycaret

# %%
from pycaret.regression import *

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57d92b8d-6d50-4c5d-925b-76abc7c51ee0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57d92b8d-6d50-4c5d-925b-76abc7c51ee0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv('merged_data.csv')

# %%
# Initialize the regression setup
reg_setup = setup(data=data, target='Sales', session_id=2023)
# Compare models and select the best one
best_model = compare_models()
# Print the output metrics
print(best_model)
# Out:
# <style type="text/css">
# #T_19e4a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_19e4a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19e4a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_19e4a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19e4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19e4a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_19e4a_row0_col1" class="data row0 col1" >2023</td>
#     </tr>
#     <tr>
#       <th id="T_19e4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19e4a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_19e4a_row1_col1" class="data row1 col1" >Sales</td>
#     </tr>
#     <tr>
#       <th id="T_19e4a_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Create and evaluate a specific model (e.g., Decision Tree)
dt = create_model('dt')

# Tune hyperparameters for the selected model
tuned_dt = tune_model(dt)

# Evaluate the final model
evaluate_model(tuned_dt)
# Out:
# <style type="text/css">
# #T_6196e_row10_col0, #T_6196e_row10_col1, #T_6196e_row10_col2, #T_6196e_row10_col3, #T_6196e_row10_col4, #T_6196e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6196e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6196e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6196e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6196e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6196e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6196e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6196e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
